# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

# %%
df1 = pd.read_csv('../Dados/CNN_Features/cnn_VGG16_128_max.csv')
df2 = pd.read_csv('../Dados/CNN_Features/cnn_VGG16_128_avg.csv')
df3 = pd.read_csv('../Dados/CNN_Features/cnn_VGG16_256_max.csv')
df4 = pd.read_csv('../Dados/CNN_Features/cnn_VGG16_256_avg.csv')
df5 = pd.read_csv('../Dados/CNN_Features/cnn_VGG19_128_max.csv')
df6 = pd.read_csv('../Dados/CNN_Features/cnn_VGG19_128_avg.csv')
df7 = pd.read_csv('../Dados/CNN_Features/cnn_VGG19_256_max.csv')
df8 = pd.read_csv('../Dados/CNN_Features/cnn_VGG19_256_avg.csv')

print(f"CNN_VGG16_128-max:{df1.shape} \nCNN_VGG16_128-avg:{df2.shape} \nCNN_VGG16_256-max: {df3.shape} \n CNN_VGG16_256-avg: {df4.shape}\nCNN_VGG19_128-max: {df5.shape} \nCNN_VGG19_128-avg: {df6.shape} \nCNN_VGG19_256-max: {df7.shape} \nCNN_VGG19_256-avg: {df8.shape}")

## Função de preparação dos dados para aplicar o HOLDOUT ##
def preparation_holdout(dataframe):
    df_features = dataframe.iloc[:, :-1]
    df_classe = dataframe['classe']

    return df_features, df_classe;

X1, y1 = preparation_holdout(df1)
X2, y2 = preparation_holdout(df2)
X3, y3 = preparation_holdout(df3)
X4, y4 = preparation_holdout(df4)
X5, y5 = preparation_holdout(df5)
X6, y6 = preparation_holdout(df6)
X7, y7 = preparation_holdout(df7)
X8, y8 = preparation_holdout(df8)
# Out:
# CNN_VGG16_128-max:(795, 513)
# CNN_VGG16_128-avg:(795, 513)
# CNN_VGG16_256-max: (795, 513)
#  CNN_VGG16_256-avg: (795, 513)
# CNN_VGG19_128-max: (795, 513)
# CNN_VGG19_128-avg: (795, 513)
# CNN_VGG19_256-max: (795, 513)
# CNN_VGG19_256-avg: (795, 513)

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.3,shuffle=True, random_state=1)
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.3,shuffle=True, random_state=1)
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size=0.3,shuffle=True, random_state=1)
X4_train, X4_test, y4_train, y4_test = train_test_split(X4, y4, test_size=0.3,shuffle=True, random_state=1)
X5_train, X5_test, y5_train, y5_test = train_test_split(X5, y5, test_size=0.3,shuffle=True, random_state=1)
X6_train, X6_test, y6_train, y6_test = train_test_split(X6, y6, test_size=0.3,shuffle=True, random_state=1)
X7_train, X7_test, y7_train, y7_test = train_test_split(X7, y7, test_size=0.3,shuffle=True, random_state=1)
X8_train, X8_test, y8_train, y8_test = train_test_split(X8, y8, test_size=0.3,shuffle=True, random_state=1)

# %%
## Aplica CNN nos dataframe
def aplicar_KNN(X_train, X_test, y_train, y_test, k_range = 10):
    for i in range(1, k_range + 1):
        kNN = KNeighborsClassifier(n_neighbors=i, metric='euclidean') 
        kNN.fit(X_train, y_train)
    
        y_pred = kNN.predict(X_test)
        print(f"Accuracy k = {i}:",metrics.accuracy_score(y_test, y_pred))
        print(confusion_matrix(y_test, y_pred))
        

## CNN_VGG16_128-max #
print("\nCNN_VGG16_128-max:")
aplicar_KNN(X1_train, X1_test, y1_train, y1_test)

## CNN_VGG16_128-avg #
print("\nCNN_VGG16_128-avg:")
aplicar_KNN(X2_train, X2_test, y2_train, y2_test)

## CNN_VGG16_256-max #
print("\nCNN_VGG16_256-max:")
aplicar_KNN(X3_train, X3_test, y3_train, y3_test)

# CNN_VGG16_256-avg #
print("\nCNN_VGG16_256-avg:")
aplicar_KNN(X4_train, X4_test, y4_train, y4_test)
# Out:
# CNN_VGG16_128-max:
# Accuracy k = 1: 0.899581589958159
# [[61  0  3  0]
#  [ 1 49  5  2]
#  [ 0  3 61  1]
#  [ 2  5  2 44]]
# Accuracy k = 2: 0.9037656903765691
# [[61  1  2  0]
#  [ 1 52  4  0]
#  [ 0  3 62  0]
#  [ 2  8  2 41]]
# Accuracy k = 3: 0.9163179916317992
# [[61  0  3  0]
#  [ 1 50  6  0]
#  [ 0  3 62  0]
#  [ 2  3  2 46]]
# Accuracy k = 4: 0.9163179916317992
# [[63  0  1  0]
#  [ 1 53  3  0]
#  [ 1  6 58  0]
#  [ 2  4  2 45]]
# Accuracy k = 5: 0.9330543933054394
# [[64  0  0  0]
#  [ 1 52  4  0]
#  [ 0  4 61  0]
#  [ 2  3  2 46]]
# Accuracy k = 6: 0.9372384937238494
# [[64  0  0  0]
#  [ 1 54  2  0]
#  [ 1  5 59  0]
#  [ 1  2  3 47]]
# Accuracy k = 7: 0.9497907949790795
# [[64  0  0  0]
#  [ 1 52  4  0]
#  [ 0  1 64  0]
#  [ 1  2  3 47]]
# Accuracy k = 8: 0.9330543933054394
# [[63  0  1  0]
#  [ 1 52  4  0]
#  [ 0  3 62  0]
#  [ 1  3  3 46]]
# Accuracy k = 9: 0.9330543933054394
# [[63  0  1  0]
#  [ 0 51  6  0]
#  [ 0  1 64  0]
#  [ 1  4  3 45]]
# Accuracy k = 10: 0.9246861924686193
# [[63  0  1  0]
#  [ 1 52  4  0]
#  [ 0  4 61  0]
#  [ 1  4  3 45]]
#
# CNN_VGG16_128-avg:
# Accuracy k = 1: 0.895397489539749
# [[59  0  4  1]
#  [ 0 49  5  3]
#  [ 0  3 62  0]
#  [ 1  4  4 44]]
# Accuracy k = 2: 0.891213389121339
# [[60  1  3  0]
#  [ 1 53  3  0]
#  [ 0  5 60  0]
#  [ 1  9  3 40]]
# Accuracy k = 3: 0.9205020920502092
# [[60  1  3  0]
#  [ 0 53  4  0]
#  [ 0  1 64  0]
#  [ 2  6  2 43]]
# Accuracy k = 4: 0.9205020920502092
# [[61  0  3  0]
#  [ 1 53  2  1]
#  [ 0  2 63  0]
#  [ 1  5  4 43]]
# Accuracy k = 5: 0.9372384937238494
# [[60  0  4  0]
#  [ 1 54  2  0]
#  [ 0  1 64  0]
#  [ 2  3  2 46]]
# Accuracy k = 6: 0.9288702928870293
# [[61  0  3  0]
#  [ 1 53  2  1]
#  [ 0  1 64  0]
#  [ 1  4  4 44]]
# Accuracy k = 7: 0.9288702928870293
# [[59  0  5  0]
#  [ 0 54  3  0]
#  [ 0  1 64  0]
#  [ 1  4  3 45]]
# Accuracy k = 8: 0.9414225941422594
# [[62  0  2  0]
#  [ 0 54  2  1]
#  [ 0  1 64  0]
#  [ 1  3  4 45]]
# Accuracy k = 9: 0.9330543933054394
# [[61  0  3  0]
#  [ 0 53  3  1]
#  [ 0  1 64  0]
#  [ 2  2  4 45]]
# Accuracy k = 10: 0.9497907949790795
# [[64  0  0  0]
#  [ 0 54  2  1]
#  [ 0  1 64  0]
#  [ 2  2  4 45]]
#
# CNN_VGG16_256-max:
# Accuracy k = 1: 0.9874476987447699
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 0  1  1 51]]
# Accuracy k = 2: 0.9707112970711297
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 0  4  2 47]]
# Accuracy k = 3: 0.9874476987447699
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 0  1  1 51]]
# Accuracy k = 4: 0.9832635983263598
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 0  1  2 50]]
# Accuracy k = 5: 0.9790794979079498
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 0  1  3 49]]
# Accuracy k = 6: 0.9748953974895398
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 0  2  3 48]]
# Accuracy k = 7: 0.9832635983263598
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 0  1  2 50]]
# Accuracy k = 8: 0.9790794979079498
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 0  2  2 49]]
# Accuracy k = 9: 0.9832635983263598
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 0  1  2 50]]
# Accuracy k = 10: 0.9790794979079498
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 0  2  2 49]]
#
# CNN_VGG16_256-avg:
# Accuracy k = 1: 0.9832635983263598
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  1 64  0]
#  [ 0  1  1 51]]
# Accuracy k = 2: 0.9707112970711297
# [[64  0  0  0]
#  [ 0 57  0  0]
#  [ 0  1 64  0]
#  [ 1  3  2 47]]
# Accuracy k = 3: 0.9832635983263598
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 1  2  0 50]]
# Accuracy k = 4: 0.9832635983263598
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 1  1  1 50]]
# Accuracy k = 5: 0.9832635983263598
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 1  2  0 50]]
# Accuracy k = 6: 0.9790794979079498
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 1  1  2 49]]
# Accuracy k = 7: 0.9790794979079498
# [[64  0  0  0]
#  [ 0 55  2  0]
#  [ 0  0 65  0]
#  [ 1  1  1 50]]
# Accuracy k = 8: 0.9790794979079498
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 1  1  2 49]]
# Accuracy k = 9: 0.9832635983263598
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 1  2  0 50]]
# Accuracy k = 10: 0.9832635983263598
# [[64  0  0  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 1  2  0 50]]

# %%
# CNN_VGG19_128-max #
print("\nCNN_VGG19_128-max:")
aplicar_KNN(X5_train, X5_test, y5_train, y5_test)

# CNN_VGG19_128-avg #
print("\nCNN_VGG19_128-avg:")
aplicar_KNN(X6_train, X6_test, y6_train, y6_test)

# CNN_VGG19_256-max #
print("\nCNN_VGG19_256-max:")
aplicar_KNN(X7_train, X7_test, y7_train, y7_test)

# CNN_VGG16_256-avg #
print("\nCNN_VGG19_256-avg:")
aplicar_KNN(X8_train, X8_test, y8_train, y8_test)
# Out:
# CNN_VGG19_128-max:
# Accuracy k = 1: 0.891213389121339
# [[57  0  7  0]
#  [ 0 51  6  0]
#  [ 1  2 62  0]
#  [ 3  5  2 43]]
# Accuracy k = 2: 0.8870292887029289
# [[60  0  4  0]
#  [ 0 53  4  0]
#  [ 1  2 62  0]
#  [ 4 10  2 37]]
# Accuracy k = 3: 0.895397489539749
# [[58  0  6  0]
#  [ 0 51  6  0]
#  [ 0  0 65  0]
#  [ 3  7  3 40]]
# Accuracy k = 4: 0.9163179916317992
# [[63  0  1  0]
#  [ 0 53  4  0]
#  [ 0  1 64  0]
#  [ 2  9  3 39]]
# Accuracy k = 5: 0.9205020920502092
# [[62  0  2  0]
#  [ 0 52  5  0]
#  [ 0  0 65  0]
#  [ 2  6  4 41]]
# Accuracy k = 6: 0.9246861924686193
# [[63  0  1  0]
#  [ 0 54  3  0]
#  [ 0  1 64  0]
#  [ 2  8  3 40]]
# Accuracy k = 7: 0.9246861924686193
# [[62  0  2  0]
#  [ 0 52  5  0]
#  [ 0  0 65  0]
#  [ 2  5  4 42]]
# Accuracy k = 8: 0.9288702928870293
# [[62  0  2  0]
#  [ 0 54  3  0]
#  [ 0  0 65  0]
#  [ 1  6  5 41]]
# Accuracy k = 9: 0.9330543933054394
# [[62  0  2  0]
#  [ 0 53  4  0]
#  [ 0  0 65  0]
#  [ 1  4  5 43]]
# Accuracy k = 10: 0.9330543933054394
# [[63  0  1  0]
#  [ 0 53  4  0]
#  [ 0  1 64  0]
#  [ 2  4  4 43]]
#
# CNN_VGG19_128-avg:
# Accuracy k = 1: 0.9288702928870293
# [[60  0  4  0]
#  [ 0 53  4  0]
#  [ 0  0 65  0]
#  [ 2  5  2 44]]
# Accuracy k = 2: 0.9163179916317992
# [[63  0  1  0]
#  [ 0 55  2  0]
#  [ 0  1 64  0]
#  [ 3 12  1 37]]
# Accuracy k = 3: 0.9288702928870293
# [[62  0  2  0]
#  [ 0 54  3  0]
#  [ 0  0 65  0]
#  [ 2  8  2 41]]
# Accuracy k = 4: 0.9414225941422594
# [[63  0  1  0]
#  [ 0 55  2  0]
#  [ 0  0 65  0]
#  [ 1  8  2 42]]
# Accuracy k = 5: 0.9372384937238494
# [[63  0  1  0]
#  [ 0 53  3  1]
#  [ 0  0 65  0]
#  [ 1  7  2 43]]
# Accuracy k = 6: 0.9330543933054394
# [[63  0  1  0]
#  [ 0 54  2  1]
#  [ 0  0 65  0]
#  [ 2  9  1 41]]
# Accuracy k = 7: 0.9288702928870293
# [[63  0  1  0]
#  [ 0 52  4  1]
#  [ 1  0 64  0]
#  [ 2  7  1 43]]
# Accuracy k = 8: 0.9330543933054394
# [[63  0  1  0]
#  [ 1 53  2  1]
#  [ 1  0 64  0]
#  [ 2  6  2 43]]
# Accuracy k = 9: 0.9414225941422594
# [[64  0  0  0]
#  [ 1 51  4  1]
#  [ 1  0 64  0]
#  [ 2  4  1 46]]
# Accuracy k = 10: 0.9372384937238494
# [[64  0  0  0]
#  [ 0 52  4  1]
#  [ 1  0 64  0]
#  [ 2  4  3 44]]
#
# CNN_VGG19_256-max:
# Accuracy k = 1: 0.9874476987447699
# [[63  0  1  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 0  0  1 52]]
# Accuracy k = 2: 0.9707112970711297
# [[63  0  1  0]
#  [ 0 57  0  0]
#  [ 1  0 64  0]
#  [ 0  2  3 48]]
# Accuracy k = 3: 0.9916317991631799
# [[63  0  1  0]
#  [ 0 57  0  0]
#  [ 0  0 65  0]
#  [ 0  1  0 52]]
# Accuracy k = 4: 0.9874476987447699
# [[63  0  1  0]
#  [ 0 57  0  0]
#  [ 0  0 65  0]
#  [ 0  1  1 51]]
# Accuracy k = 5: 0.9874476987447699
# [[63  0  1  0]
#  [ 0 57  0  0]
#  [ 0  0 65  0]
#  [ 0  1  1 51]]
# Accuracy k = 6: 0.9832635983263598
# [[63  0  1  0]
#  [ 0 57  0  0]
#  [ 0  0 65  0]
#  [ 0  2  1 50]]
# Accuracy k = 7: 0.9874476987447699
# [[63  0  1  0]
#  [ 0 57  0  0]
#  [ 0  0 65  0]
#  [ 0  1  1 51]]
# Accuracy k = 8: 0.9832635983263598
# [[63  0  1  0]
#  [ 0 57  0  0]
#  [ 0  0 65  0]
#  [ 0  2  1 50]]
# Accuracy k = 9: 0.9874476987447699
# [[63  0  1  0]
#  [ 0 57  0  0]
#  [ 0  0 65  0]
#  [ 0  1  1 51]]
# Accuracy k = 10: 0.9832635983263598
# [[63  0  1  0]
#  [ 0 57  0  0]
#  [ 0  0 65  0]
#  [ 0  2  1 50]]
#
# CNN_VGG19_256-avg:
# Accuracy k = 1: 0.9665271966527197
# [[62  0  2  0]
#  [ 0 55  2  0]
#  [ 0  1 64  0]
#  [ 1  2  0 50]]
# Accuracy k = 2: 0.9623430962343096
# [[64  0  0  0]
#  [ 0 57  0  0]
#  [ 0  2 63  0]
#  [ 1  3  3 46]]
# Accuracy k = 3: 0.9665271966527197
# [[62  0  2  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 1  2  2 48]]
# Accuracy k = 4: 0.9665271966527197
# [[62  0  2  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 1  2  2 48]]
# Accuracy k = 5: 0.9539748953974896
# [[60  0  4  0]
#  [ 0 55  1  1]
#  [ 0  0 65  0]
#  [ 1  2  2 48]]
# Accuracy k = 6: 0.9623430962343096
# [[61  0  3  0]
#  [ 0 56  1  0]
#  [ 0  0 65  0]
#  [ 1  2  2 48]]
# Accuracy k = 7: 0.9539748953974896
# [[60  0  4  0]
#  [ 0 55  1  1]
#  [ 0  0 65  0]
#  [ 1  2  2 48]]
# Accuracy k = 8: 0.9665271966527197
# [[63  0  1  0]
#  [ 0 55  2  0]
#  [ 0  0 65  0]
#  [ 1  2  2 48]]
# Accuracy k = 9: 0.9581589958158996
# [[62  0  2  0]
#  [ 0 54  2  1]
#  [ 0  0 65  0]
#  [ 1  2  2 48]]
# Accuracy k = 10: 0.9665271966527197
# [[63  0  1  0]
#  [ 0 54  2  1]
#  [ 0  0 65  0]
#  [ 1  2  1 49]]

# %%
def aplicar_KNN_with_kfold(X, y, k_range = 10, k_fold = 10):
    kf = KFold(n_splits= k_fold, random_state=1, shuffle=True)
    for i in range(1, k_range + 1):
        kNN = KNeighborsClassifier(n_neighbors=i, metric='euclidean') 
        scores = cross_val_score(kNN, X, y, scoring='accuracy', cv=kf)
        print(f'\nAccuracy (average): %.5f (%.5f) | k = {i}' % (scores.mean(), scores.std()))
        print(f'Accuracy (average): %.5f | k = {i} {scores}')

        y_pred = cross_val_predict(kNN, X, y, cv=kf)
        print(confusion_matrix(y, y_pred))

print("\n10-Fold - CNN_VGG16_128-max: ")
aplicar_KNN_with_kfold( X = X1, y = y1)

print("\n10-Fold - CNN_VGG16_128-avg: ")
aplicar_KNN_with_kfold(X = X2, y = y2)

print("\n10-Fold - CNN_VGG16_256-max: ")
aplicar_KNN_with_kfold(X = X3, y = y3)

print("\n10-Fold - CNN_VGG16_256-avg: ")
aplicar_KNN_with_kfold(X = X4, y = y4)

print("\n10-Fold - CNN_VGG19_128-max: ")
aplicar_KNN_with_kfold(X = X5, y = y5)

print("\n10-Fold - CNN_VGG19_128-avg: ")
aplicar_KNN_with_kfold(X = X6, y = y6)

print("\n10-Fold - CNN_VGG19_256-max: ")
aplicar_KNN_with_kfold(X = X7, y = y7)

print("\n10-Fold - CNN_VGG19_256-avg: ")
aplicar_KNN_with_kfold(X = X8, y = y8)
# Out:
# 10-Fold - CNN_VGG16_128-max:
#
# Accuracy (average): 0.93728 (0.03198) | k = 1
# Accuracy (average): %.5f | k = 1 [0.9125     0.9        0.8875     0.9125     0.9375     0.96202532
#  0.98734177 0.93670886 0.96202532 0.97468354]
# [[192   0   3   0]
#  [  0 185  11   4]
#  [  1   5 193   1]
#  [  1  12  12 175]]
#
# Accuracy (average): 0.92467 (0.02829) | k = 2
# Accuracy (average): %.5f | k = 2 [0.875      0.925      0.8875     0.925      0.9        0.93670886
#  0.97468354 0.93670886 0.93670886 0.94936709]
# [[192   0   3   0]
#  [  1 193   6   0]
#  [  4   7 189   0]
#  [  9  23   7 161]]
#
# Accuracy (average): 0.93473 (0.02881) | k = 3
# Accuracy (average): %.5f | k = 3 [0.9125     0.9375     0.9        0.925      0.8875     0.97468354
#  0.97468354 0.94936709 0.96202532 0.92405063]
# [[191   0   4   0]
#  [  1 186   9   4]
#  [  1   3 196   0]
#  [  4  14  12 170]]
#
# Accuracy (average): 0.92715 (0.02472) | k = 4
# Accuracy (average): %.5f | k = 4 [0.9        0.9375     0.8875     0.9125     0.9125     0.94936709
#  0.97468354 0.92405063 0.94936709 0.92405063]
# [[191   0   4   0]
#  [  2 190   7   1]
#  [  3   6 191   0]
#  [  4  19  12 165]]
#
# Accuracy (average): 0.93593 (0.02392) | k = 5
# Accuracy (average): %.5f | k = 5 [0.925      0.9625     0.9        0.9125     0.9125     0.94936709
#  0.97468354 0.93670886 0.96202532 0.92405063]
# [[191   0   4   0]
#  [  1 188  10   1]
#  [  2   2 196   0]
#  [  5  16  10 169]]
#
# Accuracy (average): 0.93593 (0.02035) | k = 6
# Accuracy (average): %.5f | k = 6 [0.9        0.95       0.9125     0.925      0.925      0.94936709
#  0.97468354 0.93670886 0.94936709 0.93670886]
# [[193   0   2   0]
#  [  1 190   9   0]
#  [  2   5 193   0]
#  [  5  17  10 168]]
#
# Accuracy (average): 0.93592 (0.02261) | k = 7
# Accuracy (average): %.5f | k = 7 [0.9        0.9625     0.925      0.9125     0.925      0.96202532
#  0.97468354 0.93670886 0.93670886 0.92405063]
# [[193   0   2   0]
#  [  1 186  12   1]
#  [  1   3 196   0]
#  [  7  14  10 169]]
#
# Accuracy (average): 0.93339 (0.01847) | k = 8
# Accuracy (average): %.5f | k = 8 [0.9125     0.9625     0.925      0.9125     0.9125     0.96202532
#  0.94936709 0.93670886 0.93670886 0.92405063]
# [[193   0   2   0]
#  [  1 187  11   1]
#  [  1   4 195   0]
#  [  6  17  10 167]]
#
# Accuracy (average): 0.93087 (0.01591) | k = 9
# Accuracy (average): %.5f | k = 9 [0.9125     0.95       0.925      0.9125     0.9125     0.93670886
#  0.96202532 0.93670886 0.93670886 0.92405063]
# [[192   0   3   0]
#  [  1 184  14   1]
#  [  1   2 197   0]
#  [  6  15  12 167]]
#
# Accuracy (average): 0.93212 (0.02311) | k = 10
# Accuracy (average): %.5f | k = 10 [0.9125     0.975      0.8875     0.925      0.925      0.92405063
#  0.96202532 0.93670886 0.93670886 0.93670886]
# [[191   0   4   0]
#  [  2 187  10   1]
#  [  1   3 196   0]
#  [  7  15  11 167]]
#
# 10-Fold - CNN_VGG16_128-avg:
#
# Accuracy (average): 0.92337 (0.02695) | k = 1
# Accuracy (average): %.5f | k = 1 [0.925      0.9375     0.875      0.9        0.9        0.94936709
#  0.96202532 0.89873418 0.93670886 0.94936709]
# [[187   0   7   1]
#  [  0 182  12   6]
#  [  1   3 194   2]
#  [  2  16  11 171]]
#
# Accuracy (average): 0.91207 (0.03240) | k = 2
# Accuracy (average): %.5f | k = 2 [0.875      0.95       0.8625     0.9        0.875      0.93670886
#  0.96202532 0.91139241 0.93670886 0.91139241]
# [[190   1   4   0]
#  [  1 194   5   0]
#  [  4  12 184   0]
#  [  5  25  13 157]]
#
# Accuracy (average): 0.93472 (0.03243) | k = 3
# Accuracy (average): %.5f | k = 3 [0.9125     0.9625     0.875      0.9125     0.9125     0.94936709
#  0.97468354 0.93670886 0.98734177 0.92405063]
# [[190   1   4   0]
#  [  0 190  10   0]
#  [  1   3 195   1]
#  [  5  16  11 168]]
#
# Accuracy (average): 0.93340 (0.02366) | k = 4
# Accuracy (average): %.5f | k = 4 [0.925      0.9625     0.8875     0.925      0.9125     0.94936709
#  0.96202532 0.92405063 0.96202532 0.92405063]
# [[190   0   5   0]
#  [  0 193   7   0]
#  [  2   3 194   1]
#  [  4  16  15 165]]
#
# Accuracy (average): 0.93343 (0.03304) | k = 5
# Accuracy (average): %.5f | k = 5 [0.95       0.9625     0.875      0.9125     0.8875     0.93670886
#  0.98734177 0.92405063 0.96202532 0.93670886]
# [[189   0   6   0]
#  [  0 187  12   1]
#  [  2   1 196   1]
#  [  4  11  15 170]]
#
# Accuracy (average): 0.93214 (0.02307) | k = 6
# Accuracy (average): %.5f | k = 6 [0.9375     0.9625     0.8875     0.925      0.9        0.94936709
#  0.96202532 0.93670886 0.93670886 0.92405063]
# [[190   0   5   0]
#  [  0 191   9   0]
#  [  4   1 194   1]
#  [  4  15  15 166]]
#
# Accuracy (average): 0.93467 (0.02886) | k = 7
# Accuracy (average): %.5f | k = 7 [0.9375     0.9625     0.8625     0.925      0.925      0.94936709
#  0.97468354 0.92405063 0.93670886 0.94936709]
# [[188   0   7   0]
#  [  0 188  12   0]
#  [  2   1 197   0]
#  [  5  13  12 170]]
#
# Accuracy (average): 0.93972 (0.03147) | k = 8
# Accuracy (average): %.5f | k = 8 [0.9375     0.9625     0.8625     0.9375     0.925      0.96202532
#  0.98734177 0.94936709 0.92405063 0.94936709]
# [[191   0   4   0]
#  [  0 191   8   1]
#  [  2   1 197   0]
#  [  7  12  13 168]]
#
# Accuracy (average): 0.93722 (0.03298) | k = 9
# Accuracy (average): %.5f | k = 9 [0.9375     0.95       0.85       0.925      0.9375     0.94936709
#  0.98734177 0.94936709 0.93670886 0.94936709]
# [[189   0   6   0]
#  [  0 188  11   1]
#  [  2   1 197   0]
#  [  6  10  13 171]]
#
# Accuracy (average): 0.94093 (0.02014) | k = 10
# Accuracy (average): %.5f | k = 10 [0.9375     0.9625     0.9        0.9375     0.925      0.96202532
#  0.97468354 0.93670886 0.93670886 0.93670886]
# [[192   0   3   0]
#  [  0 191   8   1]
#  [  2   1 197   0]
#  [  7  13  12 168]]
#
# 10-Fold - CNN_VGG16_256-max:
#
# Accuracy (average): 0.98616 (0.01045) | k = 1
# Accuracy (average): %.5f | k = 1 [1.         0.975      0.9875     1.         0.975      0.97468354
#  0.98734177 0.98734177 0.97468354 1.        ]
# [[195   0   0   0]
#  [  0 197   2   1]
#  [  0   1 199   0]
#  [  0   4   3 193]]
#
# Accuracy (average): 0.97611 (0.01042) | k = 2
# Accuracy (average): %.5f | k = 2 [0.9875     0.9625     0.9625     0.9875     0.975      0.97468354
#  0.98734177 0.98734177 0.96202532 0.97468354]
# [[195   0   0   0]
#  [  0 197   2   1]
#  [  0   1 199   0]
#  [  1   9   5 185]]
#
# Accuracy (average): 0.98112 (0.00843) | k = 3
# Accuracy (average): %.5f | k = 3 [1.         0.975      0.975      0.9875     0.975      0.98734177
#  0.97468354 0.98734177 0.97468354 0.97468354]
# [[194   0   1   0]
#  [  0 196   3   1]
#  [  0   0 200   0]
#  [  1   5   4 190]]
#
# Accuracy (average): 0.98239 (0.01006) | k = 4
# Accuracy (average): %.5f | k = 4 [1.         0.975      0.975      0.9875     0.975      0.98734177
#  0.97468354 1.         0.97468354 0.97468354]
# [[194   0   1   0]
#  [  0 197   2   1]
#  [  0   0 200   0]
#  [  1   3   6 190]]
#
# Accuracy (average): 0.97986 (0.01154) | k = 5
# Accuracy (average): %.5f | k = 5 [1.         0.975      0.9625     0.9875     0.9875     0.98734177
#  0.96202532 0.98734177 0.97468354 0.97468354]
# [[194   0   1   0]
#  [  0 195   3   2]
#  [  0   0 200   0]
#  [  1   2   7 190]]
#
# Accuracy (average): 0.97991 (0.01701) | k = 6
# Accuracy (average): %.5f | k = 6 [1.         0.975      0.9625     0.9875     0.95       0.98734177
#  1.         1.         0.96202532 0.97468354]
# [[195   0   0   0]
#  [  0 198   1   1]
#  [  0   0 200   0]
#  [  3   4   7 186]]
#
# Accuracy (average): 0.97862 (0.01263) | k = 7
# Accuracy (average): %.5f | k = 7 [0.975      0.975      0.9625     1.         0.975      0.98734177
#  1.         0.97468354 0.96202532 0.97468354]
# [[195   0   0   0]
#  [  0 195   3   2]
#  [  0   0 200   0]
#  [  2   4   6 188]]
#
# Accuracy (average): 0.97989 (0.01700) | k = 8
# Accuracy (average): %.5f | k = 8 [1.         0.975      0.9625     1.         0.95       0.98734177
#  1.         0.98734177 0.96202532 0.97468354]
# [[195   0   0   0]
#  [  0 197   2   1]
#  [  0   0 200   0]
#  [  2   4   7 187]]
#
# Accuracy (average): 0.98112 (0.01290) | k = 9
# Accuracy (average): %.5f | k = 9 [0.9875     0.975      0.9875     1.         0.9625     0.98734177
#  1.         0.97468354 0.96202532 0.97468354]
# [[195   0   0   0]
#  [  0 195   3   2]
#  [  0   0 200   0]
#  [  2   2   6 190]]
#
# Accuracy (average): 0.97862 (0.01687) | k = 10
# Accuracy (average): %.5f | k = 10 [1.         0.975      0.9625     1.         0.95       0.98734177
#  1.         0.97468354 0.96202532 0.97468354]
# [[195   0   0   0]
#  [  0 196   2   2]
#  [  0   0 200   0]
#  [  3   4   6 187]]
#
# 10-Fold - CNN_VGG16_256-avg:
#
# Accuracy (average): 0.98489 (0.01235) | k = 1
# Accuracy (average): %.5f | k = 1 [0.975      1.         0.9875     1.         0.975      1.
#  0.96202532 0.98734177 0.98734177 0.97468354]
# [[193   0   2   0]
#  [  0 194   4   2]
#  [  0   0 200   0]
#  [  0   1   3 196]]
#
# Accuracy (average): 0.97484 (0.00972) | k = 2
# Accuracy (average): %.5f | k = 2 [0.975      0.9875     0.9625     0.9875     0.9625     0.98734177
#  0.96202532 0.97468354 0.97468354 0.97468354]
# [[194   0   1   0]
#  [  0 199   1   0]
#  [  1   2 197   0]
#  [  1   7   7 185]]
#
# Accuracy (average): 0.98361 (0.01138) | k = 3
# Accuracy (average): %.5f | k = 3 [0.975      0.9875     0.9875     1.         1.         0.98734177
#  0.96202532 0.97468354 0.98734177 0.97468354]
# [[194   0   1   0]
#  [  0 196   4   0]
#  [  0   0 200   0]
#  [  1   3   4 192]]
#
# Accuracy (average): 0.98489 (0.01095) | k = 4
# Accuracy (average): %.5f | k = 4 [0.9625     0.9875     0.9875     1.         1.         0.98734177
#  0.97468354 0.98734177 0.98734177 0.97468354]
# [[194   0   1   0]
#  [  0 198   2   0]
#  [  0   0 200   0]
#  [  1   2   6 191]]
#
# Accuracy (average): 0.98362 (0.01265) | k = 5
# Accuracy (average): %.5f | k = 5 [0.9625     0.9875     0.9875     1.         1.         0.97468354
#  0.97468354 0.97468354 1.         0.97468354]
# [[194   0   1   0]
#  [  0 196   4   0]
#  [  0   0 200   0]
#  [  1   2   5 192]]
#
# Accuracy (average): 0.98237 (0.01154) | k = 6
# Accuracy (average): %.5f | k = 6 [0.9625     0.9875     0.9875     1.         0.9875     0.97468354
#  0.97468354 0.97468354 1.         0.97468354]
# [[194   0   1   0]
#  [  0 197   3   0]
#  [  0   0 200   0]
#  [  1   3   6 190]]
#
# Accuracy (average): 0.98489 (0.01232) | k = 7
# Accuracy (average): %.5f | k = 7 [0.9625     0.9875     0.9875     1.         1.         0.98734177
#  0.97468354 0.97468354 1.         0.97468354]
# [[194   0   1   0]
#  [  0 197   3   0]
#  [  0   0 200   0]
#  [  1   3   4 192]]
#
# Accuracy (average): 0.98614 (0.01313) | k = 8
# Accuracy (average): %.5f | k = 8 [0.9625     0.9875     1.         1.         1.         0.97468354
#  0.97468354 0.98734177 1.         0.97468354]
# [[194   0   1   0]
#  [  0 197   3   0]
#  [  0   0 200   0]
#  [  1   2   4 193]]
#
# Accuracy (average): 0.98237 (0.01396) | k = 9
# Accuracy (average): %.5f | k = 9 [0.95       0.9875     0.9875     1.         1.         0.98734177
#  0.97468354 0.97468354 0.98734177 0.97468354]
# [[194   0   1   0]
#  [  0 196   4   0]
#  [  0   0 200   0]
#  [  1   3   5 191]]
#
# Accuracy (average): 0.98489 (0.01232) | k = 10
# Accuracy (average): %.5f | k = 10 [0.9625     0.9875     0.9875     1.         1.         0.98734177
#  0.97468354 0.97468354 1.         0.97468354]
# [[194   0   1   0]
#  [  0 197   3   0]
#  [  0   0 200   0]
#  [  1   3   4 192]]
#
# 10-Fold - CNN_VGG19_128-max:
#
# Accuracy (average): 0.92840 (0.02951) | k = 1
# Accuracy (average): %.5f | k = 1 [0.9125     0.925      0.8625     0.95       0.9125     0.96202532
#  0.97468354 0.92405063 0.93670886 0.92405063]
# [[187   0   8   0]
#  [  0 189  10   1]
#  [  2   6 192   0]
#  [  6  15   9 170]]
#
# Accuracy (average): 0.91203 (0.03269) | k = 2
# Accuracy (average): %.5f | k = 2 [0.9        0.9125     0.8625     0.925      0.9        0.96202532
#  0.96202532 0.87341772 0.93670886 0.88607595]
# [[193   0   2   0]
#  [  0 193   6   1]
#  [  3   8 189   0]
#  [  8  37   5 150]]
#
# Accuracy (average): 0.92968 (0.03590) | k = 3
# Accuracy (average): %.5f | k = 3 [0.925      0.9        0.8625     0.925      0.9375     0.97468354
#  0.98734177 0.89873418 0.96202532 0.92405063]
# [[189   0   6   0]
#  [  0 185  12   3]
#  [  2   1 197   0]
#  [  8  16   8 168]]
#
# Accuracy (average): 0.93842 (0.02886) | k = 4
# Accuracy (average): %.5f | k = 4 [0.925      0.9375     0.8875     0.95       0.95       0.97468354
#  0.98734177 0.91139241 0.94936709 0.91139241]
# [[194   0   1   0]
#  [  0 192   8   0]
#  [  2   3 195   0]
#  [  7  18  10 165]]
#
# Accuracy (average): 0.94097 (0.02305) | k = 5
# Accuracy (average): %.5f | k = 5 [0.9375     0.925      0.9        0.9375     0.9375     0.98734177
#  0.96202532 0.93670886 0.96202532 0.92405063]
# [[194   0   1   0]
#  [  0 188  11   1]
#  [  0   1 199   0]
#  [  5  13  15 167]]
#
# Accuracy (average): 0.94475 (0.02504) | k = 6
# Accuracy (average): %.5f | k = 6 [0.9375     0.95       0.8875     0.925      0.95       0.98734177
#  0.96202532 0.93670886 0.96202532 0.94936709]
# [[194   0   1   0]
#  [  0 191   8   1]
#  [  1   2 197   0]
#  [  6  12  13 169]]
#
# Accuracy (average): 0.94098 (0.02361) | k = 7
# Accuracy (average): %.5f | k = 7 [0.9375     0.925      0.8875     0.925      0.95       0.97468354
#  0.96202532 0.93670886 0.96202532 0.94936709]
# [[192   0   3   0]
#  [  0 187  11   2]
#  [  1   1 198   0]
#  [  6  10  13 171]]
#
# Accuracy (average): 0.94598 (0.01852) | k = 8
# Accuracy (average): %.5f | k = 8 [0.9375     0.95       0.9125     0.9375     0.9375     0.97468354
#  0.97468354 0.93670886 0.96202532 0.93670886]
# [[194   0   1   0]
#  [  0 190   9   1]
#  [  2   1 197   0]
#  [  6  12  11 171]]
#
# Accuracy (average): 0.94850 (0.01616) | k = 9
# Accuracy (average): %.5f | k = 9 [0.9375     0.9375     0.925      0.95       0.9375     0.97468354
#  0.97468354 0.94936709 0.96202532 0.93670886]
# [[193   0   2   0]
#  [  0 191   8   1]
#  [  2   1 197   0]
#  [  3  11  13 173]]
#
# Accuracy (average): 0.94343 (0.02194) | k = 10
# Accuracy (average): %.5f | k = 10 [0.9375     0.95       0.9125     0.95       0.9375     0.97468354
#  0.97468354 0.92405063 0.96202532 0.91139241]
# [[193   0   2   0]
#  [  0 191   8   1]
#  [  2   2 196   0]
#  [  5  12  13 170]]
#
# 10-Fold - CNN_VGG19_128-avg:
#
# Accuracy (average): 0.92707 (0.02304) | k = 1
# Accuracy (average): %.5f | k = 1 [0.925      0.95       0.9125     0.9125     0.9125     0.96202532
#  0.96202532 0.89873418 0.93670886 0.89873418]
# [[188   0   6   1]
#  [  0 187   9   4]
#  [  2   3 193   2]
#  [  5  18   8 169]]
#
# Accuracy (average): 0.90321 (0.02960) | k = 2
# Accuracy (average): %.5f | k = 2 [0.9        0.925      0.9        0.8875     0.85       0.94936709
#  0.94936709 0.87341772 0.89873418 0.89873418]
# [[193   0   2   0]
#  [  0 192   6   2]
#  [  4   8 188   0]
#  [ 10  36   9 145]]
#
# Accuracy (average): 0.93590 (0.02197) | k = 3
# Accuracy (average): %.5f | k = 3 [0.9375     0.9375     0.9        0.95       0.9125     0.96202532
#  0.97468354 0.93670886 0.93670886 0.91139241]
# [[193   0   2   0]
#  [  0 187  11   2]
#  [  3   2 195   0]
#  [  9  15   7 169]]
#
# Accuracy (average): 0.94592 (0.02644) | k = 4
# Accuracy (average): %.5f | k = 4 [0.95       0.9625     0.9125     0.975      0.925      0.97468354
#  0.97468354 0.91139241 0.96202532 0.91139241]
# [[194   0   1   0]
#  [  0 193   7   0]
#  [  2   1 197   0]
#  [  3  23   6 168]]
#
# Accuracy (average): 0.93842 (0.02471) | k = 5
# Accuracy (average): %.5f | k = 5 [0.925      0.9625     0.9        0.9375     0.925      0.97468354
#  0.97468354 0.92405063 0.94936709 0.91139241]
# [[194   0   1   0]
#  [  0 187   9   4]
#  [  3   0 197   0]
#  [  3  19  10 168]]
#
# Accuracy (average): 0.94218 (0.02189) | k = 6
# Accuracy (average): %.5f | k = 6 [0.95       0.9375     0.9125     0.9375     0.9375     0.97468354
#  0.96202532 0.92405063 0.97468354 0.91139241]
# [[194   0   1   0]
#  [  0 189   8   3]
#  [  3   0 197   0]
#  [  3  21   7 169]]
#
# Accuracy (average): 0.94720 (0.02011) | k = 7
# Accuracy (average): %.5f | k = 7 [0.95       0.9625     0.925      0.9375     0.9375     0.98734177
#  0.94936709 0.94936709 0.96202532 0.91139241]
# [[193   0   2   0]
#  [  0 187   9   4]
#  [  4   0 196   0]
#  [  4  11   8 177]]
#
# Accuracy (average): 0.94468 (0.02264) | k = 8
# Accuracy (average): %.5f | k = 8 [0.9375     0.9625     0.925      0.95       0.925      0.98734177
#  0.93670886 0.93670886 0.97468354 0.91139241]
# [[193   0   2   0]
#  [  0 188   8   4]
#  [  3   0 197   0]
#  [  4  14   9 173]]
#
# Accuracy (average): 0.94592 (0.01597) | k = 9
# Accuracy (average): %.5f | k = 9 [0.9375     0.95       0.925      0.95       0.9625     0.94936709
#  0.94936709 0.96202532 0.96202532 0.91139241]
# [[193   0   2   0]
#  [  0 183  12   5]
#  [  2   0 198   0]
#  [  5  10   7 178]]
#
# Accuracy (average): 0.94470 (0.01789) | k = 10
# Accuracy (average): %.5f | k = 10 [0.925      0.95       0.9375     0.9375     0.9375     0.97468354
#  0.94936709 0.96202532 0.96202532 0.91139241]
# [[194   0   1   0]
#  [  0 185  11   4]
#  [  4   0 196   0]
#  [  5  11   8 176]]
#
# 10-Fold - CNN_VGG19_256-max:
#
# Accuracy (average): 0.98491 (0.01236) | k = 1
# Accuracy (average): %.5f | k = 1 [0.975      1.         0.9875     0.975      0.9875     1.
#  0.97468354 0.96202532 1.         0.98734177]
# [[193   0   2   0]
#  [  0 198   1   1]
#  [  0   2 198   0]
#  [  1   2   3 194]]
#
# Accuracy (average): 0.97611 (0.01422) | k = 2
# Accuracy (average): %.5f | k = 2 [1.         0.9875     0.9625     0.975      0.95       0.98734177
#  0.97468354 0.97468354 0.98734177 0.96202532]
# [[194   0   1   0]
#  [  0 200   0   0]
#  [  0   2 198   0]
#  [  1   8   7 184]]
#
# Accuracy (average): 0.98364 (0.01132) | k = 3
# Accuracy (average): %.5f | k = 3 [0.9875     0.9875     1.         0.9875     0.9625     0.98734177
#  0.97468354 0.97468354 1.         0.97468354]
# [[193   0   2   0]
#  [  0 199   1   0]
#  [  0   1 199   0]
#  [  3   3   3 191]]
#
# Accuracy (average): 0.98491 (0.00941) | k = 4
# Accuracy (average): %.5f | k = 4 [0.9875     0.9875     1.         0.975      0.975      0.98734177
#  0.98734177 0.97468354 1.         0.97468354]
# [[193   0   2   0]
#  [  0 200   0   0]
#  [  0   1 199   0]
#  [  1   4   4 191]]
#
# Accuracy (average): 0.98492 (0.01092) | k = 5
# Accuracy (average): %.5f | k = 5 [0.9875     0.9875     1.         0.975      0.9625     0.98734177
#  0.98734177 0.98734177 1.         0.97468354]
# [[193   0   2   0]
#  [  0 200   0   0]
#  [  0   0 200   0]
#  [  1   4   5 190]]
#
# Accuracy (average): 0.98366 (0.00981) | k = 6
# Accuracy (average): %.5f | k = 6 [0.975      0.9875     1.         0.975      0.975      0.98734177
#  0.98734177 0.97468354 1.         0.97468354]
# [[193   0   2   0]
#  [  0 200   0   0]
#  [  0   1 199   0]
#  [  1   4   5 190]]
#
# Accuracy (average): 0.98112 (0.01016) | k = 7
# Accuracy (average): %.5f | k = 7 [0.975      0.9875     1.         0.975      0.975      0.97468354
#  0.97468354 0.97468354 1.         0.97468354]
# [[192   0   3   0]
#  [  0 199   1   0]
#  [  0   1 199   0]
#  [  1   4   5 190]]
#
# Accuracy (average): 0.98114 (0.01157) | k = 8
# Accuracy (average): %.5f | k = 8 [0.9625     0.9875     1.         0.975      0.975      0.98734177
#  0.97468354 0.97468354 1.         0.97468354]
# [[193   0   2   0]
#  [  0 200   0   0]
#  [  0   1 199   0]
#  [  1   5   6 188]]
#
# Accuracy (average): 0.98112 (0.01163) | k = 9
# Accuracy (average): %.5f | k = 9 [0.975      0.9875     1.         0.975      0.975      0.98734177
#  0.97468354 0.96202532 1.         0.97468354]
# [[193   0   2   0]
#  [  0 199   0   1]
#  [  0   1 199   0]
#  [  1   4   6 189]]
#
# Accuracy (average): 0.97862 (0.01381) | k = 10
# Accuracy (average): %.5f | k = 10 [0.9625     0.9875     1.         0.975      0.9625     0.98734177
#  0.96202532 0.97468354 1.         0.97468354]
# [[192   0   3   0]
#  [  0 200   0   0]
#  [  0   1 199   0]
#  [  1   6   6 187]]
#
# 10-Fold - CNN_VGG19_256-avg:
#
# Accuracy (average): 0.97862 (0.01260) | k = 1
# Accuracy (average): %.5f | k = 1 [0.9625     1.         0.9625     0.975      0.9875     0.98734177
#  0.96202532 0.98734177 0.97468354 0.98734177]
# [[193   0   2   0]
#  [  0 194   5   1]
#  [  0   1 199   0]
#  [  1   4   3 192]]
#
# Accuracy (average): 0.96731 (0.01604) | k = 2
# Accuracy (average): %.5f | k = 2 [0.9375     0.975      0.95       0.9875     0.975      0.96202532
#  0.94936709 0.98734177 0.97468354 0.97468354]
# [[193   0   2   0]
#  [  0 197   3   0]
#  [  0   3 197   0]
#  [  1   8   9 182]]
#
# Accuracy (average): 0.97989 (0.01606) | k = 3
# Accuracy (average): %.5f | k = 3 [0.9625     0.9875     0.95       0.9875     1.         0.98734177
#  0.96202532 0.98734177 1.         0.97468354]
# [[193   0   2   0]
#  [  0 197   3   0]
#  [  0   1 199   0]
#  [  1   5   4 190]]
#
# Accuracy (average): 0.97989 (0.01149) | k = 4
# Accuracy (average): %.5f | k = 4 [0.9625     0.9875     0.9625     0.9875     0.9875     0.97468354
#  0.97468354 1.         0.98734177 0.97468354]
# [[194   0   1   0]
#  [  0 198   2   0]
#  [  0   1 199   0]
#  [  1   4   7 188]]
#
# Accuracy (average): 0.97739 (0.01229) | k = 5
# Accuracy (average): %.5f | k = 5 [0.9625     0.975      0.9625     0.975      0.9875     0.98734177
#  0.97468354 1.         0.98734177 0.96202532]
# [[193   0   2   0]
#  [  0 194   5   1]
#  [  0   0 200   0]
#  [  1   3   6 190]]
#
# Accuracy (average): 0.98116 (0.01282) | k = 6
# Accuracy (average): %.5f | k = 6 [0.9625     0.975      0.9625     0.9875     1.         0.98734177
#  0.97468354 1.         0.98734177 0.97468354]
# [[193   0   2   0]
#  [  0 197   2   1]
#  [  0   0 200   0]
#  [  1   5   4 190]]
#
# Accuracy (average): 0.98116 (0.01607) | k = 7
# Accuracy (average): %.5f | k = 7 [0.9625     0.975      0.95       1.         1.         0.98734177
#  0.97468354 1.         0.98734177 0.97468354]
# [[192   0   3   0]
#  [  0 196   3   1]
#  [  0   0 200   0]
#  [  1   2   5 192]]
#
# Accuracy (average): 0.97989 (0.01500) | k = 8
# Accuracy (average): %.5f | k = 8 [0.9625     0.975      0.95       1.         1.         0.98734177
#  0.97468354 0.98734177 0.98734177 0.97468354]
# [[193   0   2   0]
#  [  0 196   3   1]
#  [  0   0 200   0]
#  [  1   3   6 190]]
#
# Accuracy (average): 0.98116 (0.01607) | k = 9
# Accuracy (average): %.5f | k = 9 [0.9625     0.975      0.95       1.         1.         0.98734177
#  0.97468354 0.98734177 1.         0.97468354]
# [[192   0   3   0]
#  [  0 196   3   1]
#  [  0   0 200   0]
#  [  1   2   5 192]]
#
# Accuracy (average): 0.97864 (0.01374) | k = 10
# Accuracy (average): %.5f | k = 10 [0.9625     0.975      0.95       1.         0.9875     0.98734177
#  0.97468354 0.98734177 0.98734177 0.97468354]
# [[192   0   3   0]
#  [  0 196   3   1]
#  [  0   0 200   0]
#  [  1   3   6 190]]
